# %% [markdown]
# # Analysis for Continuous Improvement
#
# Author Name: Tyler Sherrill
#
# 9-digit PID: 730312196
#
# Continuous Improvement embraces a belief there is _always room to make things better_. It is a mindset and process we value and practice in this course. In this assignment, you are able to practice continuous improvement and contribute to the design ideas of the course.
#
# ## Brainstorming Ideas
#
# Reflect on your personal experiences and observations in COMP110 and **brainstorm modifications to the course that _create value_ beyond its current design**. When brainstorming, try not to be critical of the ideas you come up with regarding scale, stakeholders impacted, or for any other reasons. In the markdown cell below, brainstorm 3 to 5 ideas you think would create value for you.
#
# Each brainstormed idea should state a. the suggested change or addition, b. what the expected value created, and c. which specific stakeholders would benefit.  If helpful, expand on the following template "The course should (state idea here) because it will (state value created here) for (insert stakeholders here)."
#
# Example A: "The course should use only examples from psychology experiments because it will be more relevant for students who are psychology majors."
#
# Example B: "The course should not have post-lesson questions because they are not useful for most students in the class."

# %% [markdown]
# ### Part 1. Creative Ideation
#
# 1. The course should use data sets of thier own choice because it will more relavant for all students future projects and interests.
# 2. The course should have group projects because they are useful for most students in the class to meet new people and learn new strategies.
# 3. The course should have only in person classes without take home videos so that students can focus on exercises thougout the week nights and improve preformance.
# 4. The course should involve more creative exercises such as the turtle assignment so that sudents don't get bored with the content.
# 5. This course should have required attendence to office hours each week for students with our personal TA so that learning is enforced and more consistant for each topic.

# %% [markdown]
# ## Connecting with Available Data
#
# The data you have available for this analysis is limited to the anonymized course survey you and your peers filled out a few weeks ago. The data is found in the `survey.csv` file in this exercise directory. Each row represents an individual survey response. Each column has a description which can be found on the project write-up here: <https://22s.comp110.com/exercises/ex08.html>
#
# Review the list of available data and identify which one of your ideas _does not_, or is _least likely to_, have relevant data to support the analysis of your idea to create value. In the box below, identify which of your ideas lacks data and suggest how we might be able to collect this data in the future. One aspect of _continuous improvement_ is trying to avoid "tunnel vision" where possible improvements are not considered because there is no data available to analyze it. Identifying new data sources can unlock improvements!

# %% [markdown]
# ### Part 2. Identifying Missing Data
#
# 1. Idea without sufficient data to analyze:
#
# Idea number 5: This course should have required attendence to office hours each week for students with our personal TA so that learning is enforced and more consistant for each topic.
#
# 2. Suggestion for how to collect data to support this idea in the future:
#
# To collect data for this idea, we could collect results of grades related to amount of office hours per week, and we could include data on amount of assignments that are submitted late compared to the amount of office hours that are attended.

# %% [markdown]
# ## Choosing an Idea to Analyze
#
# Consider those of your ideas which _do_ seem likely to have relevant data to analyze. If none of your ideas do, spend a few minutes and brainstorm another idea or two with the added connection of data available on hand and add those ideas to your brainstormed ideas list.
#
# Select the one idea which you believe is _most valuable_ to analyze relative to the others and has data to support the analysis of. In the markdown cell for Part 3 below, identify the idea you are exploring and articulate why you believe it is most valuable (e.g. widest impact, biggest opportunity for improvement, simplest change for significant improvement, and so on).

# %% [markdown]
# ### Part 3. Choosing Your Analysis
#
# 1. Idea to analyze with available data:
#
# Idea number 3: The course should have only in person classes without take home videos so that students can focus on exercises thougout the week nights and improve preformance
#
# 2. This idea is more valuable than the others brainstormed because:
#
# This idea is more valuable than the other ideas because it tests how students preform with a completely syncronous class. This idea is essential to how the course is set up because if students are preforming better with syncronous classes then the class should switch so that students learn more.

# %% [markdown]
# ## Your Analysis
#
# Before you begin analysis, a reminder that we do not expect the data to support everyone's ideas and you can complete this exercise for full credit even if the data does not clearly support your suggestion or even completely refutes it. What we are looking for is a logical attempt to explore the data using the techniques you have learned up until now in a way that _either_ supports, refutes, or does not have a clear result and then to reflect on your findings after the analysis.
#
# Using the utility functions you created for the previous exercise, you will continue with your analysis in the following part. Before you begin, refer to the rubric on the technical expectations of this section in the exercise write-up.
#
# In this section, you are expected to interleave code and markdown cells such that for each step of your analysis you are starting with an English description of what you are planning to do next in a markdown cell, followed by a Python cell that performs that step of the analysis.

# %% [markdown]
# ### Part 4. Analysis
#
# We begin by changing some settings in the notebook to automatically reload changes to imported files.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# We continue by importing the helper functions from `data_utils`.

# %%
# TODO: You complete the code blocks from here forward!

from data_utils import read_csv_rows, column_values, columnar, head, select, concat, count

# %% [markdown]
# Next, ... (you take it from here and add additional code and markdown cells to read in the CSV file and process it as needed)

# %% [markdown]
# # USE THE READ_CSV_ROWS FUNCTION
#
# This code block below should read each row and output how many columns and rows their is in the data set. This will help see how many students completed the survey, and will organize the data into columns.

# %%
SURVEY_DATA_CSV_FILE_PATH: str = "../../data/survey.csv"
from data_utils import read_csv_rows

read_data_rows: list[dict[str, str]] = read_csv_rows(SURVEY_DATA_CSV_FILE_PATH)

if len(read_data_rows) == 0:
    print("Go implement read_csv_rows in data_utils.py")
    print("Be sure to save your work before re-evaluating this cell!")
else:
    print(f"Data File Read: {SURVEY_DATA_CSV_FILE_PATH}")
    print(f"{len(read_data_rows)} rows")
    print(f"{len(read_data_rows[0].keys())} columns")
    print(f"Column names: {read_data_rows[0].keys()}")
# Out:
# Data File Read: ../../data/survey.csv
# 620 rows
# 35 columns
# Column names: dict_keys(['row', 'year', 'unc_status', 'comp_major', 'primary_major', 'data_science', 'prereqs', 'prior_exp', 'ap_principles', 'ap_a', 'other_comp', 'prior_time', 'languages', 'hours_online_social', 'hours_online_work', 'lesson_time', 'sync_perf', 'all_sync', 'flipped_class', 'no_hybrid', 'own_notes', 'own_examples', 'oh_visits', 'ls_effective', 'lsqs_effective', 'programming_effective', 'qz_effective', 'oh_effective', 'tutoring_effective', 'pace', 'difficulty', 'understanding', 'interesting', 'valuable', 'would_recommend'])

# %% [markdown]
# # USE THE COLUMNAR FUNCTION
#
# This code block below will transform a table of lists of rows into a table represented by a dictionary of columns. This will help analyize how many students think they would preform better if the class was syncronous.

# %%
from data_utils import columnar

data_cols: dict[str, list[str]] = columnar(read_data_rows)

if len(data_cols.keys()) == 0:
    print("Complete your implementation of columnar in data_utilis.py")
    print("Be sure to follow the guidelines above and save your work before re-evaluating!")
else:
    print(f"{len(data_cols.keys())} columns")
    print(f"{len(data_cols['sync_perf'])} rows")
    print(f"Columns Names: {data_cols.keys()}")
# Out:
# 35 columns
# 620 rows
# Columns Names: dict_keys(['row', 'year', 'unc_status', 'comp_major', 'primary_major', 'data_science', 'prereqs', 'prior_exp', 'ap_principles', 'ap_a', 'other_comp', 'prior_time', 'languages', 'hours_online_social', 'hours_online_work', 'lesson_time', 'sync_perf', 'all_sync', 'flipped_class', 'no_hybrid', 'own_notes', 'own_examples', 'oh_visits', 'ls_effective', 'lsqs_effective', 'programming_effective', 'qz_effective', 'oh_effective', 'tutoring_effective', 'pace', 'difficulty', 'understanding', 'interesting', 'valuable', 'would_recommend'])

# %% [markdown]
# # USE THE HEAD FUNCTION
#
# This code will produce a new column based table that is the data for the first 30 students in the sample. This will help me learn patterns that could occur throughout the data, and makes it easier to tell that I am coming closer to my goal.

# %%
from data_utils import head
from tabulate import tabulate

data_cols_head: dict[str, list[str]] = head(data_cols, 30)

if len(data_cols_head.keys()) != len(data_cols.keys()) or len(data_cols_head["sync_perf"]) != 30:
    print("Complete your implementation of columnar in data_utils.py")
    print("Be sure to follow the guidelines above and save your work before re-evaluating!")

tabulate(data_cols_head, data_cols_head.keys(), "html")
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  row</th><th style="text-align: right;">  year</th><th>unc_status                 </th><th>comp_major  </th><th>primary_major                </th><th>data_science  </th><th>prereqs                                                                       </th><th>prior_exp                   </th><th>ap_principles  </th><th>ap_a  </th><th>other_comp                      </th><th>prior_time                  </th><th>languages                                                                 </th><th>hours_online_social  </th><th>hours_online_work  </th><th style="text-align: right;">  lesson_time</th><th style="text-align: right;">  sync_perf</th><th style="text-align: right;">  all_sync</th><th style="text-align: right;">  flipped_class</th><th style="text-align: right;">  no_hybrid</th><th style="text-align: right;">  own_notes</th><th style="text-align: right;">  own_examples</th><th style="text-align: right;">  oh_visits</th><th styl
# ...

# %% [markdown]
# # USE THE SELECT FUNCTION
#
# This will help me find the columns that I want to analyze and then imput them into a smaller easier to use table that only contains those columns. This will help me find the rating of improved preformace from all syncronous and the ratings of how much student wants the course to be all syncronous for the first 50 students.

# %%
from data_utils import select

selected_data: dict[str, list[str]] = select(data_cols, ["sync_perf", "all_sync"])

tabulate(head(selected_data, 50), selected_data.keys(), "html")
# Out:
# '<table>\n<thead>\n<tr><th style="text-align: right;">  sync_perf</th><th style="text-align: right;">  all_sync</th></tr>\n</thead>\n<tbody>\n<tr><td style="text-align: right;">          2</td><td style="text-align: right;">         2</td></tr>\n<tr><td style="text-align: right;">          3</td><td style="text-align: right;">         3</td></tr>\n<tr><td style="text-align: right;">          3</td><td style="text-align: right;">         4</td></tr>\n<tr><td style="text-align: right;">          5</td><td style="text-align: right;">         4</td></tr>\n<tr><td style="text-align: right;">          3</td><td style="text-align: right;">         3</td></tr>\n<tr><td style="text-align: right;">          2</td><td style="text-align: right;">         2</td></tr>\n<tr><td style="text-align: right;">          3</td><td style="text-align: right;">         3</td></tr>\n<tr><td style="text-align: right;">          2</td><td style="text-align: right;">         2</td></tr>\n<tr><td style="text-alig
# ...

# %% [markdown]
# # USE THE COUNT FUNCTION
#
# Use this list to count the number of people in each rating section of the chart.

# %%
from data_utils import count

rating_counts: dict[str, int] = count(selected_data["sync_perf"])
print(f"sync_perf_counts: {rating_counts}")

amt_want_sync: dict[str, int] = count(selected_data["all_sync"])
print(f"amt_want_sync: {amt_want_sync}")
# Out:
# sync_perf_counts: {'2': 154, '3': 94, '5': 42, '4': 101, '6': 29, '1': 149, '7': 51}
# amt_want_sync: {'2': 155, '3': 71, '4': 85, '5': 44, '1': 201, '7': 39, '6': 25}

# %% [markdown]
# # Created Helper Function: pop_rating
#
# This function should return the rating that is most common in the rating_counts and amt_want_sync columns

# %%
from data_utils import pop_rating

most_pop_perf_sync: str = pop_rating(rating_counts)
print(f"The most popular rating in Sync_perf: {most_pop_perf_sync}")

most_pop_amt_want_sync: str = pop_rating(amt_want_sync)
print(f"The most popular rating in all_sync: {most_pop_amt_want_sync}")
# Out:
# The most popular rating in Sync_perf: 2
# The most popular rating in all_sync: 1

# %% [markdown]
# # Use of a Visualization
#
# Bar chart of amount of people who picked each rating

# %%
from matplotlib import pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)
fig.suptitle("Ratings from students on how syncronous classes effect preformance and Ratings from students on prefrence of syncronous classes.")


axes[0].set_title("Preformace will improve with syncronous classes on 1-7 scale")
axes[0].bar(rating_counts.keys(), rating_counts.values())
axes[0].tick_params(axis='x', labelrotation = 45)

axes[1].set_title("Ratings 1-7 on how much students want syncronous classes")
axes[1].bar(amt_want_sync.keys(), amt_want_sync.values())
# Out:
# <BarContainer object of 7 artists>

# %% [markdown]
# ## Conclusion
#
# In the following markdown cell, write a reflective conclusion given the analysis you performed and identify recommendations.
#
# If your analysis of the data supports your idea, state your recommendation for the change and summarize the data analysys results you found which support it. Additionally, describe any extensions or refinements to this idea which might be explored further. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change.
#
# If your analysis of the data is inconclusive, summarize why your data analysis results were inconclusive in the support of your idea. Additionally, describe what experimental idea implementation or additional data collection might help build more confidence in assessing your idea. Finally, discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by experimenting with your idea.
#
# Finally, if your analysis of the data does not support it, summarize your data analysis results and why it refutes your idea. Discuss the potential costs, trade-offs, or stakeholders who may be negatively impacted by this proposed change. If you disagree with the validity of the findings, describe why your idea still makes sense to implement and what alternative data would better support it. If you agree with the validity of the data analysis, describe what alternate ideas or extensions you would explore instead.

# %% [markdown]
# ### Part 5. Conclusion
#
# The conclusion to this experiment shows that students would not prefer if comp 110 was completly syncronous. The evaluation of the pop_rating function showed that comp 110 students are very uninterested in this idea, students voted a majority of 1 on a 1-7 rating scale.
#
# Coorespondingly, students also stated that they think overall preformence would not improve if classes were all syncronous. Students voted a mojority of 2 on a 1-7 rating scale for preformace improvement.
#
# Both of these finding can easily be seen in the bar chart that was produced because there is a very overwhelming large bar in the how much students want syncronous classes and there are two major bars in the chart that asked students about if thier preformance would increase with syncronous classes.
#
# My findings completley refute my idea that students would improve preformance. The students are actually so strong on their opinion that my idea looks to be the exact opposite of what the students want comp 110 to be. Instead of having syncronous classes, students would rather have asyncronous classes, and that would also increase their preformance.
#
# There are a few costs and downsides to implementing my idea though. Some of the costs could include students not having enough time to learn the material in class because class cannot be reversed like a youtube video can. Another trade off would be students skipping class. Students might want to skip class with an all syncronous format, so the videos provide some leway in when the student will be able to learn.
#
# In the future, this experiment could again be useful to see if students methods have changed over time. Just coming out of a pandemic would likley bring a bias to the students, promoting for asyncronous classes becasue that is what feels "more normal." Addionally, this experiment could be taken to another level by comparing it to other factors of the class. If we compared test scores for people who voted for more syncronous format against the test scores for people who voted for a more asyncronous format, then we would likely be able to tell what is a better learning method for current students.
